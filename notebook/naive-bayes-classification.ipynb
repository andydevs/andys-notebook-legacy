# %% [markdown]
# # Naive Bayes Classification of Mushrooms

# %%
import pandas as pd
import numpy as np

TRAIN_FRAC = 0.75

# %% [markdown]
# Read data. Split into training and validation data.

# %%
# Our label column is "class"
label = 'class'

# Read dataset split into training and testing
# Also there might be n/a values 
df = pd.read_csv('data/mushrooms.csv')
train_df = df.sample(frac=TRAIN_FRAC)
test_df = df.drop(train_df.index)

# Print out a sample
df.sample(5)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8045     p         k           y         e       f    y               f
# 626      e         f           f         y       t    l               f
# 7134     e         k           s         g       f    n               f
# 4969     p         x           y         y       f    f               f
# 5721     p         x           y         n       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8045            c         n          b  ...                        s
# 626             w         n          w  ...                        s
# 7134            w         b          p  ...                        k
# 4969            c         b          h  ...                        k
# 5721            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 8045                      w                      p         p          w
# 626                       w                      w         p          w
# 7134                      w                      w         p          w
# 4969                      b                      b         p          w
# 5721                      p                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 8045           o         e                 w          v       p
# 626            o         p                 u          v       d
# 7134           t         p                 w          s       g
# 4969           o         l                 h          v       p
# 5721           o         e                 w          v       d
#
# [5 rows x 23 columns]

# %% [markdown]
# Prior probabilities

# %%
# Priors
priors = train_df.groupby(label).size() / len(train_df)
priors
# Out:
# class
# e    0.514853
# p    0.485147
# dtype: float64

# %% [markdown]
# Compute likelihood table

# %%
# Likelihoods
likelihoods = {
    column: train_df.groupby([column, label]).size() / train_df.groupby(label).size()
    for column in train_df.columns if column != label
}
likelihoods
# Out:
# {'cap-shape': cap-shape  class
#  b          e        0.093859
#             p        0.012542
#  c          p        0.001017
#  f          e        0.380528
#             p        0.396610
#  k          e        0.052498
#             p        0.155932
#  s          e        0.007954
#  x          e        0.465161
#             p        0.433898
#  dtype: float64,
#  'cap-surface': cap-surface  class
#  f            e        0.374165
#               p        0.195593
#  g            p        0.000678
#  s            e        0.266306
#               p        0.365424
#  y            e        0.359529
#               p        0.438305
#  dtype: float64,
#  'cap-color': cap-color  class
#  b          e        0.011454
#             p        0.032203
#  c          e        0.007318
#             p        0.002712
#  e          e        0.150811
#             p        0.225085
#  g          e        0.241807
#             p        0.204068
#  n          e        0.297486
#             p        0.259322
#  p          e        0.013999
#             p        0.021695
#  r          e        0.003182
#  u          e        0.004773
#  w          e        0.172447
#             p        0.080339
#  y          e        0.096723
#             p        0.174576
#  dtype: float64,
#  'bruises': bruises  class
#  f        e        0.340121
#           p        0.839322
#  t        e        0.659879
#           p        0.160678
#  dtype: float64,
#  'odor': odor  class
#  a     e        0.097996
#  c     p        0.048814
#  f     p        0.553898
#  l     e        0.096087
#  m     p        0.009492
#  n     e        0.805918
#        p        0.032203
#  p     p        0.065424
#  s     p        0.143051
#  y     p        0.147119
#  dtype: float64,
#  'gill-attachment': gill-attachment  class
#  a                e        0.043907
#                   p        0.005424
#  f                e        0.956093
#                   p        0.994576
#  dtype: float64,
#  'gill-spacing': gill-spacing  class
#  c             e        0.719695
#                p        0.971186
#  w             e        0.280305
#                p        0.028814
#  dtype: float64,
#  'gill-size': gill-size  class
#  b          e        0.932549
#             p        0.434237
#  n          e        0.067451
#             p        0.565763
#  dtype: float64,
#  'gill-color': gill-color  class
#  b           p        0.439661
#  e           e        0.022590
#  g           e        0.057906
#              p        0.128136
#  h           e        0.047089
#              p        0.135254
#  k           e        0.083996
#              p        0.015932
#  n           e        0.223035
#              p        0.028814
#  o           e        0.015590
#  p           e        0.199809
#              p        0.162373
#  r           p        0.007119
#  u           e        0.105950
#              p        0.012542
#  w           e        0.230353
#              p        0.064407
#  y           e        0.013681
#              p        0.005763
#  dtype: float64,
#  'stalk-shape': stalk-shape  class
#  e            e        0.385301
#               p        0.487119
#  t            e        0.614699
#               p        0.512881
#  dtype: float64,
#  'stalk-root': stalk-root  class
#  ?           e        0.167674
#              p        0.447797
#  b           e        0.458797
#              p        0.475254
#  c           e        0.124085
#              p        0.011525
#  e           e        0.202036
#              p        0.065424
#  r           e        0.047407
#  dtype: float64,
#  'stalk-surface-above-ring': stalk-surface-above-ring  class
#  f                         e        0.096723
#                            p        0.037288
#  k                         e        0.033089
#                            p        0.568475
#  s                         e        0.865415
#                            p        0.392203
#  y                         e        0.004773
#                            p        0.002034
#  dtype: float64,
#  'stalk-surface-below-ring': stalk-surface-below-ring  class
#  f                         e        0.107541
#                            p        0.034237
#  k                         e        0.031817
#                            p        0.549492
#  s                         e        0.808463
#                            p        0.396610
#  y                         e        0.052179
#                            p        0.019661
#  dtype: float64,
#  'stalk-color-above-ring': stalk-color-above-ring  class
#  b                       p        0.113898
#  c                       p        0.009492
#  e                       e        0.023544
#  g                       e        0.132676
#  n                       e        0.004773
#                          p        0.106780
#  o                       e        0.043907
#  p                       e        0.139994
#                          p        0.324068
#  w                       e        0.655107
#                          p        0.443729
#  y                       p        0.002034
#  dtype: float64,
#  'stalk-color-below-ring': stalk-color-below-ring  class
#  b                       p        0.107458
#  c                       p        0.009492
#  e                       e        0.023226
#  g                       e        0.137130
#  n                       e        0.015908
#                          p        0.113220
#  o                       e        0.043907
#  p                       e        0.139039
#                          p        0.334915
#  w                       e        0.640789
#                          p        0.429492
#  y                       p        0.005424
#  dtype: float64,
#  'veil-type': veil-type  class
#  p          e        1.0
#             p        1.0
#  dtype: float64,
#  'veil-color': veil-color  class
#  n           e        0.022272
#  o           e        0.021635
#  w           e        0.956093
#              p        0.997966
#  y           p        0.002034
#  dtype: float64,
#  'ring-number': ring-number  class
#  n            p        0.009492
#  o            e        0.874960
#               p        0.970169
#  t            e        0.125040
#               p        0.020339
#  dtype: float64,
#  'ring-type': ring-type  class
#  e          e        0.237035
#             p        0.449831
#  f          e        0.012090
#  l          p        0.331186
#  n          p        0.009492
#  p          e        0.750875
#             p        0.209492
#  dtype: float64,
#  'spore-print-color': spore-print-color  class
#  b                  e        0.010181
#  h                  e        0.012090
#                     p        0.404407
#  k                  e        0.388164
#                     p        0.059322
#  n                  e        0.419663
#                     p        0.054915
#  o                  e        0.011136
#  r                  p        0.020339
#  u                  e        0.011136
#  w                  e        0.136176
#                     p        0.461017
#  y                  e        0.011454
#  dtype: float64,
#  'population': population  class
#  a           e        0.089405
#  c           e        0.068406
#              p        0.013220
#  n           e        0.092587
#  s           e        0.212218
#              p        0.090169
#  v           e        0.281578
#              p        0.731864
#  y           e        0.255807
#              p        0.164746
#  dtype: float64,
#  'habitat': habitat  class
#  d        e        0.448934
#           p        0.328814
#  g        e        0.329621
#           p        0.187458
#  l        e        0.055043
#           p        0.145763
#  m        e        0.063633
#           p        0.010508
#  p        e        0.035635
#           p        0.257627
#  u        e        0.021635
#           p        0.069831
#  w        e        0.045498
#  dtype: float64}

# %%
column = 'odor'
sample = test_df.sample(1)
print(sample[column])
labels = priors.copy()
print(labels)
likelihood = likelihoods[column][sample[column]]
likelihood = likelihood.groupby(level=1).sum()
print(likelihood)
if 'e' not in likelihood:
    likelihood['e'] = 0
if 'p' not in likelihood:
    likelihood['p'] = 0
print(likelihood)
labels *= likelihood
labels
# Out:
# 3940    f
# Name: odor, dtype: object
# class
# e    0.514853
# p    0.485147
# dtype: float64
# class
# p    0.553898
# dtype: float64
# class
# p    0.553898
# e    0.000000
# dtype: float64
# class
# e    0.000000
# p    0.268722
# dtype: float64

# %% [markdown]
# Create classifier

# %%
def naive_bayes_classify(sample):
    labels = priors.copy()
    for column in sample.columns:
        likelihood = likelihoods[column][sample[column]]
        likelihood = likelihood.groupby(level=1).sum()
        if 'e' not in likelihood:
            likelihood['e'] = 0
        if 'p' not in likelihood:
            likelihood['p'] = 0
    return labels.idxmax()
